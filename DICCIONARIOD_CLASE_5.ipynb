# %% [markdown]
# <a href="https://colab.research.google.com/github/Alejoo22/PROGCOM-B/blob/main/DICCIONARIOD_CLASE_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DICCIONARIO
# UN DICCIONARIO ES U NA COLECCION DE ELEMENTOS DEONDE CADA UNA KEY O LLAVE Y ASOCIADA TIENE UN VALUE O VALOR. PROPIEDADES:
# DINAMICOS:PUEDEN CRECER Y AÑADIR ELEMENTOS.
# SON INEXADOS DESDE LAS LLAVES.
# PUEDEN SER ANIDADOS.
#
# SINTAXIS
#
# diccionario={}
# diccionario={llave:valor,}
# llave2:valor2,...

# %%
pedido={1:["hamburguesa","pizza","perro","gaseosa","pola","agua"],
        2:["sushi","spaguetti","gaseosa","jugo"],
        3:["ensalada","agua"]}

# %%
constructores={"nombres":["ana","valerie","roxane","julian","mayra"],
               "notas":[0.1,5,2,4.9,4.9]}

# %%
constructores.get("notas")
# Out:
# [0.1, 5, 2, 4.9, 4.9]

# %%
print(pedido)
# Out:
# {1: ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua'], 2: ['sushi', 'spaguetti', 'gaseosa', 'jugo'], 3: ['ensalada', 'agua']}

# %% [markdown]
# #yoo quiero saber que pidio mesa 1

# %%
pedido[1]
# Out:
# ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua']

# %%
if "perro" in pedido[1]:
  print("si pidieron perro")
else:
  print("no pidieron perro")
# Out:
# si pidieron perro

# %%
pedido.get(1)
# Out:
# ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua']
