# %% [markdown]
# <a href="https://colab.research.google.com/github/Alejoo22/PROGCOM-B/blob/main/Clase_3_ESTRUCUTURA_DE_LISTAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##estructura de listas
# es un tipo de dato que oermite almacenar infinita cantidad de datos en un espacio especifico llamado index.
# las listas **son mutables**
#
# sintaxis
#
# nombre_lista:[]

# %%
total_personas = 5
constructor=[]

for i in range(total_personas):
 exp = int(input(f"Ingrese la experiencia de la persona {i}: "))
 constructor.append(exp)
# Out:
# Ingrese la experiencia de la persona 0: 8
# Ingrese la experiencia de la persona 1: 5
# Ingrese la experiencia de la persona 2: 4
# Ingrese la experiencia de la persona 3: 4
# Ingrese la experiencia de la persona 4: 7

# %%
promedio=sum(constructor)/len(constructor)
promedio
for i in range(total_personas):
  if constructor[i]>promedio :
    print(f"el constructor{i} tiene mas experiencia que el promedio")
# Out:
# el constructor0 tiene mas experiencia que el promedio
# el constructor4 tiene mas experiencia que el promedio

# %%
c1=constructor
c2=constructor.copy()

# %%
c1
# Out:
# [8, 5, 4, 4, 7]

# %%
c2
# Out:
# [8, 5, 4, 4, 7]

# %% [markdown]
# ##diferencia de igual y de copy

# %%
constructor = [8, 5, 4, 4, 7]

c1 = constructor
print(c1)
# Out:
# [8, 5, 4, 4, 7]

# %%
c1[0] = 100
print("c1:", c1)
print("constructor:", constructor)
# Out:
# c1: [100, 5, 4, 4, 7]
# constructor: [100, 5, 4, 4, 7]

# %%
c2 = constructor.copy()

print(c2)
# Out:
# [100, 5, 4, 4, 7]

# %%
c2[0] = 999
print("c2:", c2)
print("constructor:", constructor)
# Out:
# c2: [999, 5, 4, 4, 7]
# constructor: [100, 5, 4, 4, 7]

# %% [markdown]
# ##clase 4

# %%
import random
shuffle

# %%
agenda = []

while True:
    print("==== GUILD WARS - AGENDA =====")
    print("1. Ver agenda")
    print("2. Agregar actividad")
    print("3. Buscar actividad")
    print("4. Eliminar actividad")
    print("5. Mostrar cantidad de actividades")
    print("6. Ver primera actividad")
    print("7. Ver última actividad")
    print("8. Ordenar agenda")
    print("9. Salir")

    opcion = input("Elige una opción: ")

    match opcion:
        case "1":
            if len(agenda) == 0:
                print("La agenda está vacía")
            else:
                print("\nActividades en la agenda:")
                for i in range(len(agenda)):
                    print(f"{i + 1}. {agenda[i]}")

        case "2":
            actividad = input("Escribe la actividad a agregar: ")
            agenda.append(actividad)
            print(f"'{actividad}' fue agregada a la agenda")

        case "3":
            buscar = input("Escribe la actividad a buscar: ")

            if buscar in agenda:
                print(f"'{buscar}' sí está en la agenda")
            else:
                print(f"'{buscar}' no se encontró en la agenda")

        case "4":
            eliminar = input("Escribe la actividad a eliminar: ")

            if eliminar in agenda:
                agenda.remove(eliminar)
                print(f"'{eliminar}' fue eliminada")
            else:
                print(f"'{eliminar}' no existe en la agenda")

        case "5":
            print(f"Cantidad de actividades: {len(agenda)}")

        case "6":
            if len(agenda) == 0:
                print("La agenda está vacía")
            else:
                print(f"Primera actividad: {agenda[0]}")

        case "7":
            if len(agenda) == 0:
                print("La agenda está vacía")
            else:
                print(f"Última actividad: {agenda[-1]}")

        case "8":
            agenda.sort()
            print("Agenda ordenada alfabéticamente")

        case "9":
            print("Saliendo del programa... ¡Nos vemos!")
            break

        case _:
            print("Opción no válida, intenta de nuevo")
# Out:
# ==== GUILD WARS - AGENDA =====
# 1. Ver agenda
# 2. Agregar actividad
# 3. Buscar actividad
# 4. Eliminar actividad
# 5. Mostrar cantidad de actividades
# 6. Ver primera actividad
# 7. Ver última actividad
# 8. Ordenar agenda
# 9. Salir
# Elige una opción: 1
# La agenda está vacía
#
# ==== GUILD WARS - AGENDA =====
# 1. Ver agenda
# 2. Agregar actividad
# 3. Buscar actividad
# 4. Eliminar actividad
# 5. Mostrar cantidad de actividades
# 6. Ver primera actividad
# 7. Ver última actividad
# 8. Ordenar agenda
# 9. Salir
# Elige una opción: 2
# Escribe la actividad a agregar: supo
# 'supo' fue agregada a la agenda
#
# ==== GUILD WARS - AGENDA =====
# 1. Ver agenda
# 2. Agregar actividad
# 3. Buscar actividad
# 4. Eliminar actividad
# 5. Mostrar cantidad de actividades
# 6. Ver primera actividad
# 7. Ver última actividad
# 8. Ordenar agenda
# 9. Salir
